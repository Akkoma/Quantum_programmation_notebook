# %% [markdown]
# <a href="https://colab.research.google.com/github/Akkoma/Quantum_programmation_notebook/blob/main/Maxcut_prob.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install qiskit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 20.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 40.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.4/39.4 MB 13.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.5/107.5 kB 7.3 MB/s eta 0:00:00
# ...

# %%
from qiskit.quantum_info import Statevector, SparsePauliOp
from qiskit.circuit.library import QAOAAnsatz
from qiskit.primitives import Estimator, StatevectorSampler
from qiskit.visualization import plot_histogram
from scipy.optimize import minimize
import numpy as np

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit.primitives import StatevectorSampler

qr = QuantumRegister(size=5, name='q')
cr = ClassicalRegister(size=5, name='c')
qc = QuantumCircuit(5,5)

Hc = SparsePauliOp("IIIZZ")+SparsePauliOp("IIZIZ")+SparsePauliOp("IIZZI")+SparsePauliOp("IZIZI")+SparsePauliOp("ZZIII")+SparsePauliOp("ZIZII")

zero = Statevector.from_int(0, dims = 2)
one = Statevector.from_int(1, dims = 2)

psi = one^zero^one^one^zero

exp_val_th = Estimator().run(circuits = qc, observables = Hc, shots = None).result().values.real

# %%
binary_list = []

for i in range(32):
    binary_value = format(i, '05b')  # Convertir l'entier en binaire sur 5 bits
    binary_list.append(binary_value)


for i in range(32):
  qc = QuantumCircuit(5,5)

  qc.draw()

# %%
ansatz = QAOAAnsatz(Hc,reps = 2)
ansatz.decompose(reps = 4).draw()
# Out:
#      ┌────────────┐                                                    »
# q_0: ┤ U(π/2,0,π) ├──■────────────────────■────■────────────────────■──»
#      ├────────────┤┌─┴─┐┌──────────────┐┌─┴─┐  │                    │  »
# q_1: ┤ U(π/2,0,π) ├┤ X ├┤ Rz(2.0*γ[0]) ├┤ X ├──┼────────────────────┼──»
#      ├────────────┤└───┘└──────────────┘└───┘┌─┴─┐┌──────────────┐┌─┴─┐»
# q_2: ┤ U(π/2,0,π) ├──────────────────────────┤ X ├┤ Rz(2.0*γ[0]) ├┤ X ├»
#      ├────────────┤                          └───┘└──────────────┘└───┘»
# q_3: ┤ U(π/2,0,π) ├────────────────────────────────────────────────────»
#      ├────────────┤                                                    »
# q_4: ┤ U(π/2,0,π) ├────────────────────────────────────────────────────»
#      └────────────┘                                                    »
# «     ┌───────────────┐                                               »
# «q_0: ┤ R(2.0*β[0],0) ├───────────────────────────────────────────────»
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# QiskitError                               Traceback (most recent call last)
# <ipython-input-30-17d73f487f47> in <cell line: 1>()
# ----> 1 ansatz.cost_operator()
#
# /usr/local/lib/python3.10/dist-packages/qiskit/quantum_info/operators/base_operator.py in __call__(self, *qargs)
#      68         n_qargs = len(qargs)
#      69         if n_qargs not in self._op_shape.num_qargs:
# ---> 70             raise QiskitError(
#      71                 "qargs does not match the number of operator qargs "
#      72                 f"({n_qargs} not in {self._op_shape.num_qargs})"
#
# QiskitError: 'qargs does not match the number of operator qargs (0 not in (5, 5))'
